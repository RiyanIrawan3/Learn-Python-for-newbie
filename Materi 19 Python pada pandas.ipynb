# %%
pwd #cara cari file dimana data python
# Out:
# 'C:\\Users\\User'

# %%
import pandas as pd

# %%
my_item = pd.read_csv('kapal_titanic.csv') #ketika abis endscore harus pencet tab

# %%
my_item
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
my_item.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
my_item.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
my_item.to_csv('itemcsv.csv', index=False)

# %%
pd.read_csv('itemcsv.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
my_item.to_excel('itemexcel.xlsx', index=False, sheet_name='asik')

# %%
pd.read_excel('itemexcel.xlsx')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
itemhtml = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
itemhtml #cara membaca html
# Out:
# [                             Bank Name           City  ST   CERT  \
#  0                 The First State Bank  Barboursville  WV  14361
#  1                   Ericson State Bank        Ericson  NE  18265
#  2     City National Bank of New Jersey         Newark  NJ  21111
#  3                        Resolute Bank         Maumee  OH  58317
#  4                Louisa Community Bank         Louisa  KY  58112
#  ..                                 ...            ...  ..    ...
#  556                 Superior Bank, FSB       Hinsdale  IL  32646
#  557                Malta National Bank          Malta  OH   6629
#  558    First Alliance Bank & Trust Co.     Manchester  NH  34264
#  559  National State Bank of Metropolis     Metropolis  IL   3815
#  560                   Bank of Honolulu       Honolulu  HI  21029
#
#                     Acquiring Institution       Closing Date
#  0                         MVB Bank, Inc.      April 3, 2020
# ...

# %%
type(itemhtml) #tanda sukar braket kaya tanda kurung
# Out:
# list

# %%
itemhtml[0]
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
#membaca data titanic 
from sqlalchemy import create_engine #pandas membuat memory

# %%
mesin = create_engine('sqlite:///:memory:')

# %% [markdown]
# #### Meng import data titanic ke sql

# %%
my_item.to_sql('myitemsql', con=mesin)

# %%
pd.read_sql('myitemsql', con=mesin)
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#      deck
# 0    None
# 1       C
# 2    None
# 3       C
# ...
