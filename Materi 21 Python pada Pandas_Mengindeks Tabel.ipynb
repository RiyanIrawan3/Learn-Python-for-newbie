# %%
import pandas as pd

# %%
items = pd.read_csv('kapal_titanic.csv')

# %%
items
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
items['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
my_item = items['sex']

# %%
my_item
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
type(my_item) #type datanya series
# Out:
# pandas.core.series.Series

# %%
items[['age','sex']]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(items[['age','sex']]) #data frame karna di satu kolom lebih dari satu data.seperti di atas adalah data frame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # dot notation

# %%
items.age # dot ini artinya titik
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
items['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# #### Data yang di hasilkan sama saja dengan hasil dot notation

# %%
#kalo di tes boolean
items.age.equals(items['age'])
# Out:
# True

# %% [markdown]
# ##### Untuk metode slicing iloc tapi kita harus tau indeksnya

# %% [markdown]
# # iloc
# ## .iloc[baris, kolom]

# %%
items.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
items.iloc[0]
# Out:
# survived       0
# pclass         3
# sex         male
# age           22
# sibsp          1
# parch          0
# fare        7.25
# embarked       S
# deck         NaN
# Name: 0, dtype: object

# %%
items.iloc[0:10] #untuk pemelihan baris
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
items.iloc[:,4] #kalo kolomnya brantakan series
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: sibsp, Length: 891, dtype: int64

# %%
items.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %%
items.iloc[-5:-1,-4:] #-4 itu kolom, sedangkan -1 itu yang terqakhir tidak masuk
# Out:
#      parch   fare embarked deck
# 886      0  13.00        S  NaN
# 887      0  30.00        S    B
# 888      2  23.45        S  NaN
# 889      0  30.00        C    C

# %%
items.iloc[[0,3,7]] #ini cara untuk mengambil data pada kolom
# Out:
#    survived  pclass     sex   age  sibsp  parch    fare embarked deck
# 0         0       3    male  22.0      1      0   7.250        S  NaN
# 3         1       1  female  35.0      1      0  53.100        S    C
# 7         0       3    male   2.0      3      1  21.075        S  NaN

# %%
items.iloc[[2,3,5,6],[2,3,4]] #jadi ini ada  baris dan kolom 2,3,5,6 ini baris sedangkan 2,3,4 adalah kolom
# Out:
#       sex   age  sibsp
# 2  female  26.0      0
# 3  female  35.0      1
# 5    male   NaN      0
# 6    male  54.0      0

# %% [markdown]
# # loc
# ## loc['nama','nama kolom']

# %% [markdown]
# #### untuk melakukan slicing tapi tidak mengetahui indeksnya bagaimana

# %%
items = pd.read_csv('kapal_titanic.csv', index_col='embarked')

# %%
items #diatas cara mengganti nomor kolom jadi string
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# C                1       1  female  38.0      1      0  71.2833    C
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
# C                1       1    male  26.0      0      0  30.0000    C
# Q                0       3    male  32.0      0      0   7.7500  NaN
#
# [891 rows x 8 columns]

# %%
#kita bisa melakukan indexing
items.loc['S']
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# S                0       1    male  54.0      0      0  51.8625    E
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  28.0      0      0  10.5000  NaN
# S                0       3    male  25.0      0      0   7.0500  NaN
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
#
# [644 rows x 8 columns]

# %%
items.loc['S','sex']
# Out:
# embarked
# S      male
# S    female
# S    female
# S      male
# S      male
#       ...
# S      male
# S      male
# S      male
# S    female
# S    female
# Name: sex, Length: 644, dtype: object

# %%
items.loc['S',['age','fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# S         28.0  10.5000
# S         25.0   7.0500
# S         27.0  13.0000
# S         19.0  30.0000
# S          NaN  23.4500
#
# [644 rows x 2 columns]

# %%
items.loc[['S','Q'],['age','fare']] #kita bisa baris dan kolom pada loc jika tidak mengetahui indkexing
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# Q          NaN   7.7500
# Q          NaN   6.9500
# Q          NaN   7.7500
# Q         39.0  29.1250
# Q         32.0   7.7500
#
# [721 rows x 2 columns]
