# %%
pwd
# Out:
# 'C:\\Users\\User'

# %%
import pandas as pd

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# #### Distribution plot. dimana kita tau data secara makro

# %%
sns.distplot(dataku.age); # ; bisa menghilangkan info matplotlib

# %%
sns.distplot(dataku.age, kde=False) #buat menghilangkan garis ini

# %%
sns.distplot(dataku.age, kde=False, bins=100); #bins disini cara diagram menjadi lebih terpisah

# %%
sns.distplot(dataku.age, kde=True, bins=50);

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.jointplot(x='age', y='fare', data=dataku);

# %%
import scipy.stats as stat

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, data=dataku);
# ko efisien nya 0 = maka tidak ada hubungan sedangkan koefisien 1 maka ada hubungan
# Out:
# D:\New folder\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
from warnings import filterwarnings
filterwarnings('ignore') #cara menghilngkan warning

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, kind='reg', data=dataku);
# lihat ada garis itu regresi

# %%
#kita akan membuang sebuah outlier
# versi 1 manual outlier
dataku.fare[dataku.fare>400]
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# Name: fare, dtype: float64

# %%
data_baru= dataku.drop([258,679,737])

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, kind='reg', data=data_baru);
#lihat data di atas 400 tidak ada

# %%
# versi 2 yaitu desstribusi Z(normal)
from scipy.stats import zscore

# %%
import numpy as np
nilai_Z = zscore(dataku.fare)

# %%
nilai_Z
# Out:
# array([-5.02445171e-01,  7.86845294e-01, -4.88854258e-01,  4.20730236e-01,
#        -4.86337422e-01, -4.78116429e-01,  3.95813561e-01, -2.24083121e-01,
#        -4.24256141e-01, -4.29555021e-02, -3.12172378e-01, -1.13845709e-01,
#        -4.86337422e-01, -1.87093118e-02, -4.90279793e-01, -3.26266659e-01,
#        -6.19988892e-02, -3.86670720e-01, -2.85997284e-01, -5.02948539e-01,
#        -1.24919787e-01, -3.86670720e-01, -4.86756223e-01,  6.63597416e-02,
#        -2.24083121e-01, -1.64441595e-02, -5.02948539e-01,  4.64700108e+00,
#        -4.89776426e-01, -4.89442190e-01, -9.02720170e-02,  2.30172882e+00,
#        -4.92377828e-01, -4.37007438e-01,  1.00606170e+00,  3.98582080e-01,
#        -5.02863973e-01, -4.86337422e-01, -2.85997284e-01, -4.22073541e-01,
#        -4.57645492e-01, -2.25593223e-01, -4.89442190e-01,  1.88762532e-01,
#        -4.89776426e-01, -4.86337422e-01, -3.36334002e-01, -4.92377828e-01,
# ...

# %%
nilai_Z_abs = np.abs(nilai_Z)

# %%
nilai_Z_abs #ini angka abssolut ini angka yang ga ada min
# Out:
# array([5.02445171e-01, 7.86845294e-01, 4.88854258e-01, 4.20730236e-01,
#        4.86337422e-01, 4.78116429e-01, 3.95813561e-01, 2.24083121e-01,
#        4.24256141e-01, 4.29555021e-02, 3.12172378e-01, 1.13845709e-01,
#        4.86337422e-01, 1.87093118e-02, 4.90279793e-01, 3.26266659e-01,
#        6.19988892e-02, 3.86670720e-01, 2.85997284e-01, 5.02948539e-01,
#        1.24919787e-01, 3.86670720e-01, 4.86756223e-01, 6.63597416e-02,
#        2.24083121e-01, 1.64441595e-02, 5.02948539e-01, 4.64700108e+00,
#        4.89776426e-01, 4.89442190e-01, 9.02720170e-02, 2.30172882e+00,
#        4.92377828e-01, 4.37007438e-01, 1.00606170e+00, 3.98582080e-01,
#        5.02863973e-01, 4.86337422e-01, 2.85997284e-01, 4.22073541e-01,
#        4.57645492e-01, 2.25593223e-01, 4.89442190e-01, 1.88762532e-01,
#        4.89776426e-01, 4.86337422e-01, 3.36334002e-01, 4.92377828e-01,
#        2.11917743e-01, 2.90024222e-01, 1.50673744e-01, 4.91371093e-01,
# ...

# %%
filter_data = (nilai_Z_abs<3)

# %%
dataku_baru = dataku[filter_data]

# %%
dataku_baru #baris tinggal 871
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [871 rows x 9 columns]

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, kind='reg', data=dataku_baru);

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, kind='hex', data=data_baru);

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, kind='kde', data=data_baru);

# %%
sns.pairplot(dataku); # ini diagram untuk numerik. diagonal ini histrogram

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
