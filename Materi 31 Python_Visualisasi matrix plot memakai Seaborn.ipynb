# %%
import pandas as pd
import seaborn as sns
sns.set()

# %%
Data = pd.read_csv('kapal_titanic.csv')
Data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
Data.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(Data.corr())

# %%
sns.heatmap(Data.corr(), annot=True)

# %%
sns.heatmap(Data.corr(), annot=True, cmap='Reds');

# %%
Data1 = pd.read_csv('kapal_titanic.csv', index_col)
Data1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e1918fbef068> in <module>
# ----> 1 Data1 = pd.read_csv('kapal_titanic.csv', index_col)
#       2 Data1.head()
#
# NameError: name 'index_col' is not defined

# %%
sns.heatmap(Data1.iloc[:,[0,1,4]].head(), annot=True, cmap='BuPu');

# %%
item = sns.load_dataset('flights')
item.head()

# %%
item

# %%
item.pivot_table(index='month', columns='year', values='passengers')

# %%
item_pivot = item.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(item_pivot, cmap='gist_yarg');

# %%
sns.heatmap(item_pivot, cmap='gist_yarg', linecolor='yellow',linewidth=3);

# %%
sns.clustermap(item_pivot);
# diagram seperti pohon disebut dendogram

# %%
sns.clustermap(item_pivot, cmap='coolwarm');

# %%
sns.clustermap(item_pivot, cmap='coolwarm', standard_scale=1);
